# %% [markdown]
# <a href="https://colab.research.google.com/github/bibhacodex/python-practice-/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# celsius to fahrenheit conversion of temperature

# %%
a = int(input("Enter temperature in celsius: "))
print(f"temperature in farenheit:",9*a/5+32)
# Out:
# Enter temperature in celsius: 109
# temperature in farenheit: 228.2

# %% [markdown]
# find the largest number from three input number

# %%
a = int(input("Enter 1st number:  "))
b = int(input("Enter 2nd number:  "))
c = int(input("Enter 3rd number:  "))
print("Largest number :",max(a, b, c))
# Out:
# Enter 1st number:  45
# Enter 2nd number:  68
# Enter 3rd number:  89
# Largest number : 89

# %% [markdown]
# calculate the total and percentage of the student's 5 subject marks
#
# > Add blockquote

# %%
a = int(input("Enter first subject no:"))
b = int(input("Enter second subject no:"))
c = int(input("Enter third subject no:"))
d = int(input("Enter fourth subject no:"))
e = int(input("Enter fifth subject no:"))
print("Total marks:",a+b+c+d+e)
print("percentage of the marks:",(a+b+c+d+e)/500*100,"%" )
# Out:
# Enter first subject no:1
# Enter second subject no:2
# Enter third subject no:3
# Enter fourth subject no:4
# Enter fifth subject no:5
# Total marks: 15
# percentage of the marks: 3.0 %

# %% [markdown]
# calculate simple interest

# %%
a = int(input("Enter your principal amount: "))
b= int(input("Enter your rate of interest(in percentage): "))
c = int(input("Enter time for invest amount"))
print("Simple interest :", (a*b*c)/100)
# Out:
# Enter your principal amount: 1000
# Enter your rate of interest(in percentage): 4
# Enter time for invest amount1
# Simple interest : 40.0

# %% [markdown]
# check the no.'s negative, positive or zero

# %%
def check_number(a):
  if a==0:
    return "zero"
  elif a>0:
    return "positive"
  else:
    return "negative"

a = int(input("Enter no:"))
result = check_number(a)
print(result)
# Out:
# Enter no:0
# zero
